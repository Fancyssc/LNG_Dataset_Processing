# %%
import pandas as pd
import gc
from matplotlib import pyplot as plt

# %% [markdown]
# ## 数据加载
# ### 转换成格式合理的.csv文件

# %%
lng_path = "data/lng2.csv"
lng_new_path = "data/lng2_new.csv"
content = open(lng_path)
with open(lng_new_path, "w") as f:
    for line in content:
        f.write(line.replace(" ", ","))
with open(lng_new_path, 'r+') as f:
    content = f.read()
    f.seek(0, 0)
    f.write('id,time,status,velocity,longitude,latitude,draft\n' + content)

# %% [markdown]
# ### 读取csv并且绘制原始图像

# %%
dataFrame = pd.read_csv("data/lng2_new.csv",sep=",")
plt.scatter(dataFrame['longitude'],dataFrame['latitude'],s=1)
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.show()

# %% [markdown]
# ## 数据预处理

# %%
data_tmp = dataFrame[(dataFrame['draft'] != 0) & (dataFrame['velocity'] == 0) & (dataFrame['velocity'] <300) ]
plt.scatter(data_tmp["longitude"],data_tmp["latitude"],s=1)
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.show()

# %% [markdown]
# ## 聚类分析

# %%
lng_long_lati = data_tmp[['longitude','latitude']]
# Out:
#           longitude   latitude
# 81       -93.691132  29.430000
# 90       -93.691269  29.429684
# 91       -93.691299  29.429701
# 93       -93.691299  29.429684
# 96       -93.691299  29.429701
# ...             ...        ...
# 7896832  103.651276   1.217855
# 7896858  103.648239   1.214497
# 7896862  103.648277   1.214635
# 7896865  103.648209   1.214813
# 7896866  103.648125   1.214922
#
# [3667513 rows x 2 columns]
